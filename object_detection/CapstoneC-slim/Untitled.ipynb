# %%
import pandas as pd

# %%
mapSummary = pd.read_csv("mAP_summary.csv")
inferenceData = pd.read_csv("InferenceData.csv")
inferenceData150 = pd.read_csv("InferenceData_150_scaled.csv")
inferenceData300 = pd.read_csv("InferenceData_300_scaled.csv")
inferenceData450 = pd.read_csv("InferenceData_450_scaled.csv")
inferenceData600 = pd.read_csv("InferenceData_600_scaled.csv")
inferenceDataScaled = pd.read_csv("InferenceData_scaled.csv")

# %%
mapSummary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 5 columns):
# Unnamed: 0    96 non-null int64
# Algorthm      96 non-null object
# mAP           96 non-null float64
# Condition     96 non-null object
# imageWidth    96 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.8+ KB

# %%
mapSummary.head()
# Out:
#    Unnamed: 0                              Algorthm       mAP Condition  \
# 0           0  faster_rcnn_inception_v2_coco_custom  0.282007       day
# 1           1         faster_rcnn_inception_v2_coco  0.130057       day
# 2           2             faster_rcnn_resnet50_coco  0.280898       day
# 3           3           mask_rcnn_inception_v2_coco  0.176690       day
# 4           4                   rfcn_resnet101_coco  0.184652       day
#
#    imageWidth
# 0         150
# 1         150
# 2         150
# 3         150
# 4         150

# %%
inferenceData150.head()
# Out:
#    Class  Confidence       top      left    bottom     right  Width  Height  \
# 0      8    0.995397  0.362293  0.109977  0.839752  0.773196    150     112
# 1      8    0.987935  0.360631  0.331123  0.868939  0.819403    150     112
# 2      8    0.789560  0.561882  0.644394  0.718899  0.886092    150     112
# 3      8    0.653652  0.544107  0.343138  0.840966  0.802309    150     112
# 4      3    0.613290  0.407543  0.181609  0.590846  0.407153    150     112
#
#                                   Model  Inference Time (Sec)  \
# 0  faster_rcnn_inception_v2_coco_custom              1.354489
# 1  faster_rcnn_inception_v2_coco_custom              1.354489
# 2  faster_rcnn_inception_v2_coco_custom              1.354489
# 3  faster_rcnn_inception_v2_coco_custom              1.354489
# 4  faster_rcnn_inception_v2_coco_custom              1.354489
#
#   Driving Condition                   ImageID  ImageWidth
# 0               day  000000154000_reSized.jpg         150
# ...
